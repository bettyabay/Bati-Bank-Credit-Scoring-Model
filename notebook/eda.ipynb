# %%
import sys
import pandas as pd

# %%
sys.path.append('../Scripts')
from eda import *

df =  EDA('../Data/data.csv')

# %% [markdown]
# **EDA**

# %% [markdown]
# **1. Overview of the Data**

# %%
df.overview_of_data()
# Out:
# ### Overview of Data ###
# Number of Rows: 95662
# Number of Columns: 16
#
# Data Types:
# TransactionId            object
# BatchId                  object
# AccountId                object
# SubscriptionId           object
# CustomerId               object
# CurrencyCode             object
# CountryCode               int64
# ProviderId               object
# ProductId                object
# ProductCategory          object
# ChannelId                object
# Amount                  float64
# Value                     int64
# TransactionStartTime     object
# PricingStrategy           int64
# FraudResult               int64
# dtype: object
#
# Missing Values:
# TransactionId           0
# BatchId                 0
# AccountId               0
# SubscriptionId          0
# CustomerId              0
# CurrencyCode            0
# CountryCode             0
# ProviderId              0
# ProductId               0
# ProductCategory         0
# ChannelId               0
# ...

# %% [markdown]
# - Overview of the Data: The dataset contains 95,662 rows and 16 columns.

# %% [markdown]
# **2.Summary Stastistics**

# %%
df.summary_statistics()
# Out:
# ### Summary Statistics for Numerical Data ###
#        CountryCode        Amount         Value  PricingStrategy   FraudResult
# count      95662.0  9.566200e+04  9.566200e+04     95662.000000  95662.000000
# mean         256.0  6.717846e+03  9.900584e+03         2.255974      0.002018
# std            0.0  1.233068e+05  1.231221e+05         0.732924      0.044872
# min          256.0 -1.000000e+06  2.000000e+00         0.000000      0.000000
# 25%          256.0 -5.000000e+01  2.750000e+02         2.000000      0.000000
# 50%          256.0  1.000000e+03  1.000000e+03         2.000000      0.000000
# 75%          256.0  2.800000e+03  5.000000e+03         2.000000      0.000000
# max          256.0  9.880000e+06  9.880000e+06         4.000000      1.000000
#
# ### Summary Statistics for Categorical Data ###
#               TransactionId        BatchId       AccountId  \
# count                 95662          95662           95662
# ...

# %% [markdown]
# **3. Distribution of Numerical Features**

# %%
df.distribution_of_numerical_features()
# Out:
# Numerical Columns: Index(['CountryCode', 'Amount', 'Value', 'PricingStrategy', 'FraudResult'], dtype='object')

# %% [markdown]
# **4.Distribution of catagorical features**

# %%
df.distribution_of_categorical_features()
# Out:
# c:\Users\USER\Desktop\KAIM\Bati-Bank-Credit-Scoring-Model\notebook\../Scripts\eda.py:62: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=self.data, x=col, palette='pastel')
# c:\Users\USER\Desktop\KAIM\Bati-Bank-Credit-Scoring-Model\notebook\../Scripts\eda.py:62: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=self.data, x=col, palette='pastel')
# c:\Users\USER\Desktop\KAIM\Bati-Bank-Credit-Scoring-Model\notebook\../Scripts\eda.py:62: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# **5.Correlation Analysis**

# %%
df.correlation_analysis()
# Out:
# ### Correlation Analysis ###
#
# Correlation Matrix:
#                  CountryCode    Amount     Value  PricingStrategy  FraudResult
# CountryCode              NaN       NaN       NaN              NaN          NaN
# Amount                   NaN  1.000000  0.989692        -0.061931     0.557370
# Value                    NaN  0.989692  1.000000        -0.017020     0.566739
# PricingStrategy          NaN -0.061931 -0.017020         1.000000    -0.033821
# FraudResult              NaN  0.557370  0.566739        -0.033821     1.000000
#
# Means:
# CountryCode         256.000000
# Amount             6717.846433
# Value              9900.583941
# PricingStrategy       2.255974
# FraudResult           0.002018
# dtype: float64
#
# Standard Deviations:
# CountryCode             0.000000
# Amount             123306.797164
# Value              123122.087776
# PricingStrategy         0.732924
# FraudResult             0.044872
# dtype: float64
#
# Counts of Non-NA Values:
# ...

# %% [markdown]
# - Amount and Value: There is a strong positive correlation (0.989) between the Amount and Value, indicating that as the Amount increases, the Value tends to increase as well.
#
# - Amount and FraudResult: There is a moderate positive correlation (0.557) between Amount and FraudResult, suggesting that higher transaction amounts are somewhat associated with higher fraud results.

# %% [markdown]
# **6. Identifying Missing Values**

# %%
df.identify_missing_values()
# Out:
# No missing values in the dataset.

# %% [markdown]
# **7. Outlier Detection**

# %%
df.detect_outliers()
# Out:
# 0 outliers detected in CountryCode using IQR method. (0.00% of data)
# 24441 outliers detected in Amount using IQR method. (25.55% of data)
# 9021 outliers detected in Value using IQR method. (9.43% of data)
# 15814 outliers detected in PricingStrategy using IQR method. (16.53% of data)
# 193 outliers detected in FraudResult using IQR method. (0.20% of data)
# {'CountryCode': Empty DataFrame
#  Columns: [TransactionId, BatchId, AccountId, SubscriptionId, CustomerId, CurrencyCode, CountryCode, ProviderId, ProductId, ProductCategory, ChannelId, Amount, Value, TransactionStartTime, PricingStrategy, FraudResult]
#  Index: [],
#  'Amount':               TransactionId         BatchId       AccountId  \
#  3         TransactionId_380  BatchId_102363   AccountId_648
#  6      TransactionId_118063  BatchId_118460  AccountId_2442
#  32       TransactionId_5351  BatchId_110904  AccountId_2540
#  39     TransactionId_104700   BatchId_55274  AccountId_2126
# ...

# %%
df.handle_outliers()
# Out:
# Handling outliers for CountryCode using default method (Winsorization)
# Applying log transformation to Amount
# Applying Winsorization to Value
# Applying binning to PricingStrategy
# c:\Users\USER\Desktop\KAIM\Bati-Bank-Credit-Scoring-Model\.myenv\lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Retaining outliers in FraudResult, as they are crucial for analysis
# Cleaned data saved to ../Data/clean_data.csv
#               TransactionId         BatchId       AccountId  \
# 0       TransactionId_76871   BatchId_36123  AccountId_3957
# 1       TransactionId_73770   BatchId_15642  AccountId_4841
# 2       TransactionId_26203   BatchId_53941  AccountId_4229
# 3         TransactionId_380  BatchId_102363   AccountId_648
# 4       TransactionId_28195   BatchId_38780  AccountId_4841
# ...                     ...             ...             ...
# ...
